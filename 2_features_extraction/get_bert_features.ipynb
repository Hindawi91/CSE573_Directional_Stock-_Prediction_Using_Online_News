# %%
import torch
from transformers import BertTokenizer, BertModel
import pandas as pd
import numpy as np
import pickle

# %%
with open('../1_data_pre_processing/AmznLabelledNewsData.pkl', 'rb') as f:
    labelled_amzn_news_df = pickle.load(f)
    
with open('../1_data_pre_processing/AaplLabelledNewsData.pkl', 'rb') as f:
    labelled_aapl_news_df = pickle.load(f)

# %%
# print(labelled_aapl_news_df.head(10))
print(labelled_amzn_news_df.head(10))
# Out:
#         news_timestamp stock_timestamp            source  \
# 0  2017-12-15 12:04:00      2017-12-18  seekingalpha.com
# 1  2017-12-21 12:04:00      2017-12-22  seekingalpha.com
# 2  2017-12-21 12:27:00      2017-12-22     thestreet.com
# 3  2017-12-22 00:00:00      2017-12-26     investors.com
# 4  2017-12-22 20:57:00      2017-12-26         yahoo.com
# 5  2017-12-27 00:00:00      2017-12-28     investors.com
# 6  2017-12-27 11:43:00      2017-12-28  seekingalpha.com
# 7  2017-12-28 00:00:00      2017-12-29     investors.com
# 8  2017-12-28 11:39:00      2017-12-29  seekingalpha.com
# 9  2017-12-28 11:39:00      2017-12-29  seekingalpha.com
#
#                                               tokens  label
# 0  ['amazon', 'soon', 'sell', 'pull', 'e', 'platf...      1
# 1  ['line', 'cashier', 'similar', 'fashion', 'fut...     -1
# 2  ['fit', 'fang', 'stock', 'amazon', 'alphabet',...     -1
# 3                       ['amazon', 'cloud', 'china']      1
# 4  ['stream', 'stick', 'plus', 'offer', 'play', '...      1
# 5  ['new', 'year', 'find', 'almost', 'shape', 're...     -1
# 6  ['amazon', 'ad', 'product', 'platform', 'push'...     -1
# 7  ['amazon', 'strong', 'holiday', 'result', 'ros...     -1
# 8  ['crown', 'bin', 'look', 'give', 'kingdom', 'h...     -1
# 9  ['crown', 'bin', 'look', 'give', 'kingdom', 'h...     -1

# %%
df =labelled_amzn_news_df.loc[0:50]
df
# Out:
#          news_timestamp stock_timestamp                source  \
# 0   2017-12-15 12:04:00      2017-12-18      seekingalpha.com
# 1   2017-12-21 12:04:00      2017-12-22      seekingalpha.com
# 2   2017-12-21 12:27:00      2017-12-22         thestreet.com
# 3   2017-12-22 00:00:00      2017-12-26         investors.com
# 4   2017-12-22 20:57:00      2017-12-26             yahoo.com
# 5   2017-12-27 00:00:00      2017-12-28         investors.com
# 6   2017-12-27 11:43:00      2017-12-28      seekingalpha.com
# 7   2017-12-28 00:00:00      2017-12-29         investors.com
# 8   2017-12-28 11:39:00      2017-12-29      seekingalpha.com
# 9   2017-12-28 11:39:00      2017-12-29      seekingalpha.com
# 10  2017-12-28 13:13:00      2017-12-29         thestreet.com
# 11  2017-12-29 00:00:00      2018-01-02         investors.com
# 12  2017-12-29 00:00:00      2018-01-02         investors.com
# 13  2017-12-29 00:00:00      2018-01-02         investors.com
# 14  2017-12-29 00:00:00      2018-01-02         investors.com
# 15  2017-12-29 13:48:00      2018-01-02         thestreet.com
# 16  2017-12-30 15:31:00      2018-01-02      googlejuices.com
# 17  2017-12-31 00:00:00      2018-01-02       morningstar.com
# 18  2017-12-31 11:00:00      2018-01-02             cnyes.com
# 19  2017-12-31 15:00:00      2018-01-02             yahoo.com
# 20  2018-01-01 00:00:00      2018-01-02               msn.com
# 21  2018-01-01 00:00:00      2018-01-02       morningstar.com
# 22  2018-01-01 00:00:00      2018-01-02            thefly.com
# 23  2018-01-01 00:00:00      2018-01-02            nasdaq.com
# 24  2018-01-01 00:00:00      2018-01-02               wsj.com
# 25  2018-01-01 00:00:00      2018-01-02               wsj.com
# 26  2018-01-01 00:00:00      2018-01-02               wsj.com
# 27  2018-01-01 00:00:00      2018-01-02               wsj.com
# 28  2018-01-01 00:00:00      2018-01-02               wsj.com
# 29  2018-01-01 00:00:00      2018-01-02               msn.com
# 30  2018-01-01 01:29:00      2018-01-02  financialnewsusa.com
# 31  2018-01-01 01:47:00      2018-01-02            sunmag.net
# 32  2018-01-01 08:47:00      2018-01-02             yahoo.com
# 33  2018-01-01 10:40:00      2018-01-02    topstocksforum.com
# 34  2018-01-01 13:00:00      2018-01-02      etfdailynews.com
# 35  2018-01-01 15:18:00      2018-01-02             cnfol.com
# 36  2018-01-01 20:30:00      2018-01-02     virtualmining.com
# 37  2018-01-02 00:00:00      2018-01-03       morningstar.com
# 38  2018-01-02 00:00:00      2018-01-03       marketwatch.com
# 39  2018-01-02 00:00:00      2018-01-03                wn.com
# 40  2018-01-02 00:00:00      2018-01-03                wn.com
# 41  2018-01-02 00:00:00      2018-01-03       morningstar.com
# 42  2018-01-02 00:00:00      2018-01-03       morningstar.com
# 43  2018-01-02 00:00:00      2018-01-03               msn.com
# 44  2018-01-02 00:00:00      2018-01-03            nasdaq.com
# 45  2018-01-02 00:00:00      2018-01-03       morningstar.com
# 46  2018-01-02 00:00:00      2018-01-03         investors.com
# 47  2018-01-02 00:00:00      2018-01-03            nasdaq.com
# 48  2018-01-02 00:00:00      2018-01-03              fool.com
# 49  2018-01-02 00:00:00      2018-01-03         investors.com
# 50  2018-01-02 00:00:00      2018-01-03         investors.com
#
#                                                tokens  label
# 0   ['amazon', 'soon', 'sell', 'pull', 'e', 'platf...      1
# 1   ['line', 'cashier', 'similar', 'fashion', 'fut...     -1
# 2   ['fit', 'fang', 'stock', 'amazon', 'alphabet',...     -1
# 3                        ['amazon', 'cloud', 'china']      1
# 4   ['stream', 'stick', 'plus', 'offer', 'play', '...      1
# 5   ['new', 'year', 'find', 'almost', 'shape', 're...     -1
# 6   ['amazon', 'ad', 'product', 'platform', 'push'...     -1
# 7   ['amazon', 'strong', 'holiday', 'result', 'ros...     -1
# 8   ['crown', 'bin', 'look', 'give', 'kingdom', 'h...     -1
# 9   ['crown', 'bin', 'look', 'give', 'kingdom', 'h...     -1
# 10  ['speak', 'report', 'said', 'tech', 'giant', '...     -1
# 11  ['amazon', 'trade', 'trump', 'tweet', 'unit', ...      1
# 12  ['discount', 'took', 'amazon', 'e', 'offer', '...      1
# 13  ['x', 'view', 'stock', 'quot', 'page', 'rate',...      1
# 14  ['fought', 'remain', 'posit', 'slip', 'amazon'...      1
# 15  ['higher', 'growth', 'go', 'fang', 'acronym', ...      1
# 16  ['android', 'pay', 'babi', 'call', 'market', '...      1
# 17  ['share', 'enjoy', 'gain', 'blue', 'chip', 'ge...      1
# 18  ['us', 'class', 'ko', 'augment', 'ar', 'virtua...      1
# 19  ['trend', 'tech', 'affect', 'near', 'know', 's...      1
# 20  ['news', 'trump', 'target', 'amazon', 'call', ...      1
# 21    ['away', 'stock', 'mani', 'investor', 'amazon']      1
# 22  ['concern', 'disrupt', 'market', 'joint', 'ama...      1
# 23  ['stock', 'amazon', 'enter', 'actual', 'year',...      1
# 24  ['p', 'dow', 'indic', 'global', 'broad', 'mark...      1
# 25  ['micro', 'arm', 'hold', 'alphabet', 'amazon',...      1
# 26  ['amazon', 'alphabet', 'team', 'nation', 'step...      1
# 27  ['amazon', 'unit', 'parcel', 'up', 'mark', 'fo...      1
# 28  ['street', 'journal', 'justin', 'alphabet', 'a...      1
# 29  ['news', 'trump', 'target', 'amazon', 'call', ...      1
# 30  ['amazon', 'parent', 'alphabet', 'share', 'sto...      1
# 31  ['huge', 'hit', 'viewer', 'like', 'amazon', 'h...      1
# 32  ['huge', 'hit', 'viewer', 'like', 'amazon', 'h...      1
# 33  ['month', 'trump', 'amazon', 'look', 'squash',...      1
# 34  ['amazon', 'enter', 'actual', 'year', 'ago', '...      1
# 35  ['jami', 'justin', 'donald', 'trump', 'alphabe...      1
# 36  ['amazon', 'enter', 'actual', 'year', 'ago', '...      1
# 37  ['p', 'hold', 'ba', 'exact', 'corp', 'jan', 'a...      1
# 38  ['general', 'construct', 'backdrop', 'paint', ...      1
# 39  ['next', 'channel', 'bit', 'ly', 'check', 'sig...      1
# 40  ['peter', 'line', 'almanac', 'vol', 'cool', 's...      1
# 41  ['note', 'portion', 'u', 'market', 'gain', 'qu...      1
# 42    ['away', 'stock', 'mani', 'investor', 'amazon']      1
# 43  ['fox', 'million', 'dollar', 'idea', 'news', '...      1
# 44    ['fang', 'stock', 'amazon', 'alphabet', 'also']      1
# 45  ['share', 'enjoy', 'gain', 'blue', 'chip', 'ge...      1
# 46  ['follow', 'gain', 'tuesday', 'tech', 'rich', ...      1
# 47  ['maker', 'fiber', 'optic', 'network', 'laser'...      1
# 48  ['maker', 'fiber', 'optic', 'network', 'laser'...      1
# 49                      ['amazon', 'move', 'respect']      1
# 50  ['final', 'amazon', 'near', 'move', 'tuesday',...      1

# %%
# Load pre-trained BERT model and tokenizer

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

# Assuming 'df' is your DataFrame with a 'tokens' column
text_data = df['tokens'].apply(lambda tokens: ' '.join(tokens))

# Tokenize and obtain embeddings for each document
embeddings = []
for text in text_data:
    # Tokenize the text and convert to tensor
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    
    # Forward pass through BERT model
    with torch.no_grad():
        outputs = model(**inputs)
    
    # Extract the embeddings for the [CLS] token (the first token in the sequence)
    cls_embedding = outputs.last_hidden_state[:, 0, :]

    # Convert the tensor to a NumPy array and append to the list
    embeddings.append(cls_embedding.numpy())

# Convert the list of embeddings to a NumPy array
embedding_matrix = np.vstack(embeddings)

# Create a DataFrame with the embeddings
df_embeddings = pd.DataFrame(embedding_matrix)

# Concatenate the embeddings with your original DataFrame
df_combined = pd.concat([df, df_embeddings], axis=1)

# Display the DataFrame with embeddings
print(df_combined)
# Out:
#          news_timestamp stock_timestamp                source  \
# 0   2017-12-15 12:04:00      2017-12-18      seekingalpha.com
# 1   2017-12-21 12:04:00      2017-12-22      seekingalpha.com
# 2   2017-12-21 12:27:00      2017-12-22         thestreet.com
# 3   2017-12-22 00:00:00      2017-12-26         investors.com
# 4   2017-12-22 20:57:00      2017-12-26             yahoo.com
# 6   ['amazon', 'ad', 'product', 'platform', 'push'...     -1 -0.416669
# 7   ['amazon', 'strong', 'holiday', 'result', 'ros...     -1 -0.288803
# 8   ['crown', 'bin', 'look', 'give', 'kingdom', 'h...     -1 -0.161114
# 9   ['crown', 'bin', 'look', 'give', 'kingdom', 'h...     -1 -0.161114
# 10  ['speak', 'report', 'said', 'tech', 'giant', '...     -1 -0.317459
# 11  ['amazon', 'trade', 'trump', 'tweet', 'unit', ...      1 -0.326031
# 12  ['discount', 'took', 'amazon', 'e', 'offer', '...      1 -0.319736
# 13  ['x', 'view', 'stock', 'quot', 'page', 'rate',...      1 -0.339543
# 14  ['fought', 'remain', 'posit', 'slip', 'amazon'...      1 -0.234869
# 15  ['higher', 'growth', 'go', 'fang', 'acronym', ...      1 -0.256090
# 16  ['android', 'pay', 'babi', 'call', 'market', '...      1 -0.320401
# 17  ['share', 'enjoy', 'gain', 'blue', 'chip', 'ge...      1 -0.319458
# 18  ['us', 'class', 'ko', 'augment', 'ar', 'virtua...      1 -0.453407
# 19  ['trend', 'tech', 'affect', 'near', 'know', 's...      1 -0.274335
# 20  ['news', 'trump', 'target', 'amazon', 'call', ...      1 -0.119709
# 21    ['away', 'stock', 'mani', 'investor', 'amazon']      1 -0.200588
# 22  ['concern', 'disrupt', 'market', 'joint', 'ama...      1 -0.330222
# 23  ['stock', 'amazon', 'enter', 'actual', 'year',...      1 -0.252653
# 24  ['p', 'dow', 'indic', 'global', 'broad', 'mark...      1 -0.336948
# 25  ['micro', 'arm', 'hold', 'alphabet', 'amazon',...      1 -0.280209
# 26  ['amazon', 'alphabet', 'team', 'nation', 'step...      1 -0.226532
# 27  ['amazon', 'unit', 'parcel', 'up', 'mark', 'fo...      1 -0.381186
# 28  ['street', 'journal', 'justin', 'alphabet', 'a...      1 -0.268014
# 29  ['news', 'trump', 'target', 'amazon', 'call', ...      1 -0.140813
# 30  ['amazon', 'parent', 'alphabet', 'share', 'sto...      1 -0.286070
# 31  ['huge', 'hit', 'viewer', 'like', 'amazon', 'h...      1 -0.189105
# 32  ['huge', 'hit', 'viewer', 'like', 'amazon', 'h...      1 -0.189105
# 33  ['month', 'trump', 'amazon', 'look', 'squash',...      1 -0.316280
# 34  ['amazon', 'enter', 'actual', 'year', 'ago', '...      1 -0.242520
# 35  ['jami', 'justin', 'donald', 'trump', 'alphabe...      1 -0.158474
# 36  ['amazon', 'enter', 'actual', 'year', 'ago', '...      1 -0.242520
# 37  ['p', 'hold', 'ba', 'exact', 'corp', 'jan', 'a...      1 -0.389591
# 38  ['general', 'construct', 'backdrop', 'paint', ...      1 -0.257253
# 39  ['next', 'channel', 'bit', 'ly', 'check', 'sig...      1 -0.318713
# 40  ['peter', 'line', 'almanac', 'vol', 'cool', 's...      1 -0.335436
# 41  ['note', 'portion', 'u', 'market', 'gain', 'qu...      1 -0.201287
# 42    ['away', 'stock', 'mani', 'investor', 'amazon']      1 -0.200588
# 43  ['fox', 'million', 'dollar', 'idea', 'news', '...      1 -0.276217
# 44    ['fang', 'stock', 'amazon', 'alphabet', 'also']      1 -0.252022
# 45  ['share', 'enjoy', 'gain', 'blue', 'chip', 'ge...      1 -0.319458
# 46  ['follow', 'gain', 'tuesday', 'tech', 'rich', ...      1 -0.257040
# 47  ['maker', 'fiber', 'optic', 'network', 'laser'...      1 -0.296785
# 48  ['maker', 'fiber', 'optic', 'network', 'laser'...      1 -0.239046
# 49                      ['amazon', 'move', 'respect']      1 -0.178806
# 50  ['final', 'amazon', 'near', 'move', 'tuesday',...      1 -0.202837
#
#            1         2         3         4  ...       758       759       760  \
# 0   0.625130 -0.040261 -0.281267 -0.237748  ...  0.230825  0.198264 -0.559813
# 1   0.688582 -0.055293 -0.180222 -0.216500  ...  0.251903  0.301774 -0.668991
# 2   0.589210 -0.183654 -0.204690 -0.206434  ...  0.129316  0.251051 -0.606210
# 3   0.335447 -0.202900 -0.263661 -0.265079  ...  0.114866  0.048925 -0.483848
# 4   0.949468 -0.024457 -0.435650 -0.129910  ... -0.041862  0.471650 -0.779330
# 5   0.803863  0.156584 -0.310561 -0.119514  ...  0.088757  0.474131 -0.766882
# 6   0.834599  0.055468 -0.304341 -0.133352  ...  0.002646  0.354852 -0.673518
# 7   0.813395  0.125957 -0.299620 -0.174303  ...  0.010594  0.381450 -0.695317
# 8   0.711663 -0.144755 -0.201422 -0.234691  ...  0.238972  0.378810 -0.617091
# 9   0.711663 -0.144755 -0.201422 -0.234691  ...  0.238972  0.378810 -0.617091
# 10  0.745000 -0.085834 -0.245791 -0.143430  ...  0.281884  0.383061 -0.674276
# 11  0.690934 -0.144915 -0.221793 -0.214339  ...  0.140572  0.254062 -0.577581
# 12  0.805405  0.087010 -0.332277 -0.144935  ...  0.032306  0.377359 -0.713319
# 13  0.940038  0.007957 -0.392423 -0.149198  ...  0.046265  0.502177 -0.695499
# 14  0.734931  0.125742 -0.342769 -0.156580  ... -0.046012  0.411733 -0.779688
# 15  0.660467 -0.155071 -0.095128 -0.261235  ...  0.356144  0.298054 -0.545875
# 16  0.935772  0.003289 -0.465962 -0.058932  ... -0.054192  0.516120 -0.805488
# 17  0.888889  0.152038 -0.383670 -0.093829  ... -0.057580  0.392118 -0.779418
# 18  0.802771  0.101027 -0.260683 -0.218434  ...  0.182364  0.450673 -0.615501
# 19  0.758677 -0.133916 -0.160027 -0.245042  ...  0.280706  0.268358 -0.646825
# 20  0.881115  0.133845 -0.186952 -0.174655  ...  0.088954  0.160552 -0.677983
# 21  0.433893 -0.174854 -0.179367 -0.128182  ...  0.065096  0.183981 -0.517241
# 22  0.871563  0.047643 -0.349547 -0.189584  ...  0.157696  0.464555 -0.627536
# 23  0.738663 -0.112896 -0.270727 -0.073598  ...  0.155919  0.328009 -0.813087
# 24  0.814013 -0.128752 -0.294330 -0.224148  ...  0.115009  0.536462 -0.656210
# 25  0.600576 -0.247402 -0.251367 -0.154333  ...  0.280422  0.250456 -0.667282
# 26  0.715166 -0.170086 -0.190674 -0.139175  ...  0.086665  0.230603 -0.646952
# 27  0.849256 -0.052129 -0.342495 -0.126485  ...  0.118095  0.574254 -0.745249
# 28  0.840585  0.055159 -0.246035 -0.259261  ...  0.138607  0.402584 -0.598036
